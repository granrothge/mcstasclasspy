# %% [markdown]
# # Example of plotting and manipulating 1D Data.

# %% [markdown]
# Necessary imports

# %%
import mcstasclasspy.mcmonloader as mcm
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# Load the data for the source spectrum

# %%
source = mcm.load_ascii_monitor('../tests/data/Source_spectrum.dat')

# %% [markdown]
# Most of the commands are overloaded python, numpy or matplotlib. For example the errorbar method works just like the matplotlib except you pass the axis in if you like. The tick params are then straight matplotlib

# %%
f,ax =plt.subplots()
source.errorbar(ax=ax,fmt='.')
ax.tick_params(colors='magenta',which='both')
ax.yaxis.label.set_color('magenta')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# This command assumes there is a peak and calcualtes the area under it the weighted mean and a width

# %%
source.peakstats()
# Out:
# (5885991095180.179, 3.2713885524724384, 1.667215990737818)

# %% [markdown]
# can't remember which output is which?

# %%
source.peakstats?

# %% [markdown]
# want to see the code

# %%
source.peakstats??

# %% [markdown]
# now let's multiply the y axis by 10. I have overloaded the ```__mult__``` operator

# %%
source2=source*10

# %%
f2,ax2=plt.subplots()
source2.errorbar(ax=ax2,fmt='d')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# What happened to the title and the labels? You can look in/ modify the instance

# %%
source2.ylabel
# Out:
# ''

# %%
source2.ylabel='I*10'

# %%
f3,ax3=plt.subplots()
source2.errorbar(ax=ax3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ErrorbarContainer object of 3 artists>
