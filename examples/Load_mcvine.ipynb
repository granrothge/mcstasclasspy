# %%
import mcstasclasspy.mcmonloader as mcm
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
dat= mcm.load_mcvine_histogram('../tests/data/ienergy.h5')

# %%
f,ax=plt.subplots()
dat.errorbar(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ErrorbarContainer object of 3 artists>
